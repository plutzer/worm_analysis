# %%
import pandas as pd
comp_frame = pd.read_csv('aggregate_measurements_save.tsv',delimiter = '\t')
comp_frame
# Out:
#                worm_num  t_reg_mask_90  t_int_mask_90  t_perc_mask_90  \
# 0   2018-05-19t1711.png          82822          105.0      222.287711
# 1   2018-05-20t1711.png             30         3841.0        0.104022
# 2   2018-05-25t0911.png             39         7374.9        0.212708
# 3   2018-05-23t0511.png             48         6997.4        0.108586
# 4   2018-05-21t0111.png             24         6170.8        0.117848
# 5   2018-05-21t1711.png             37         6322.0        0.127766
# 6   2018-05-24t0511.png             52         6977.0        0.172263
# 7   2018-05-22t0111.png             43         6501.5        0.109206
# 8   2018-05-25t1311.png             48         7182.8        0.203823
# 9   2018-05-21t0911.png             35         7111.0        0.122459
# 10  2018-05-24t1311.png             46         6473.4        0.225491
# 11  2018-05-19t2111.png          74304          106.0      209.250122
# ...
